# %% [markdown]
# # PCA on Breast Cancer Gene Expression Data
#
# This project performs Principal Component Analysis (PCA) on breast cancer gene-expression data.
#
# Genes analyzed:
# - GATA3
# - XBP1
#
# The PCA projection demonstrates separation between ER+ and ER− breast cancer samples.
#
# The analysis reproduces the biological interpretation of Figure 1 from the referenced breast cancer study.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load class labels
class_df = pd.read_csv(
    "../data/class.tsv",
    sep="\t",
    header=None
)

# Load gene expression data
expression_df = pd.read_csv(
    "../data/filtered.tsv.gz",
    sep="\t",
    compression="gzip"
)

# Load gene mapping file
columns_df = pd.read_csv(
    "../data/columns.tsv.gz",
    sep="\t",
    compression="gzip",
    comment="#"
)

# %%
import gzip

with gzip.open(
    "../data/columns.tsv.gz",
    "rt"
) as file:

    for i in range(10):
        print(file.readline())

print(columns_df.head())
print(columns_df.columns)
columns_df[
    columns_df["GeneSymbol"].isin(
        ["XBP1", "GATA3"]
    )
]
expression_df.columns = (
    expression_df.columns.str.strip()
)
gata3 = expression_df["4359"]

xbp1 = expression_df["4404"]

labels = class_df[0]
# Out:
# #ID =
#
# #TYPE = Probe type, e.g. cDNA_clone for probes derived from a cDNA clone
#
# #ReporterID = Brief probe ID/name, e.g. ID for the cDNA clone used to produce probe
#
# #GeneName = Gene description annotation for probe
#
# #GeneSymbol = Gene symbol annotation for probe
#
# #UniGeneCluster = UniGene cluster ID annotation for probe
#
# #UniGeneBuild = The UniGene build from which probe annotations were collected
#
# #GB_LIST = GeneBank accession and/or RefSeq number annotation for probe
#
#    ID               TYPE     ReporterID  \
# 0   1  cDNA_landinglight  IMAGE:2580289
# 1   2  cDNA_landinglight  IMAGE:2580289
# 2   3         cDNA_clone   BC DDP 2 E12
# 3   4         cDNA_clone   BC DDP 2 G12
# 4   5         cDNA_clone   BC TAX 1 A06
#
#                                            GeneName GeneSymbol UniGeneCluster  \
# 0                                       B-actin_1/4       ACTB      Hs.520640
# 1                                       B-actin_1/8       ACTB      Hs.520640
# 2                   AL122097 DKFZp434P1215(unknown)        NaN            NaN
# 3                                           strange        NaN            NaN
# 4  XM_017216 hypothetical protein FLJ21127(unknown)        NaN            NaN
#
#    UniGeneBuild               GB_LIST EntrezGene       vector  InsertLength  \
# 0         188.0  AW081870,  NM_001101         60  pCMV-SPORT6           NaN
# 1         188.0  AW081870,  NM_001101         60  pCMV-SPORT6           NaN
# 2           NaN                   NaN        NaN          NaN           NaN
# 3           NaN                   NaN        NaN          NaN           NaN
# 4           NaN                   NaN        NaN          NaN           NaN
#
#    ARRAY_BLOCK  BLOCK_COLUMN  BLOCK_ROW       SPOT_ID CLONE_ID
# 0          1.0           1.0        1.0           NaN      NaN
# 1          1.0           2.0        1.0           NaN      NaN
# 2          1.0           3.0        1.0  BC DDP 2 E12      NaN
# 3          1.0           4.0        1.0  BC DDP 2 G12      NaN
# 4          1.0           5.0        1.0  BC TAX 1 A06      NaN
# Index(['ID', 'TYPE', 'ReporterID', 'GeneName', 'GeneSymbol', 'UniGeneCluster',
#        'UniGeneBuild', 'GB_LIST', 'EntrezGene', 'vector', 'InsertLength',
#        'ARRAY_BLOCK', 'BLOCK_COLUMN', 'BLOCK_ROW', 'SPOT_ID', 'CLONE_ID'],
#       dtype='str')

# %%
plt.figure(figsize=(8,6))

for label in [0, 1]:

    mask = labels == label

    plt.scatter(
        gata3[mask],
        xbp1[mask],
        label=f"Class {label}"
    )

plt.xlabel("GATA3 Expression")

plt.ylabel("XBP1 Expression")

plt.title("Breast Cancer Gene Expression")

plt.legend()

plt.grid(True)

# SAVE BEFORE SHOW
plt.savefig(
    "../figures/figure1a.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
selected_data = pd.DataFrame({
    "GATA3": gata3,
    "XBP1": xbp1
})
scaler = StandardScaler()

scaled_data = scaler.fit_transform(
    selected_data
)
pca = PCA(n_components=1)

pc1 = pca.fit_transform(
    scaled_data
)
plt.figure(figsize=(10,4))

for label in [0, 1]:

    mask = labels == label

    plt.scatter(
        pc1[mask],
        np.zeros(sum(mask)),
        label=f"Class {label}"
    )

plt.xlabel("Principal Component 1")

plt.title("Projection on PC1")

plt.legend()

plt.grid(True)

# SAVE BEFORE SHOW
plt.savefig(
    "../figures/figure1c.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
print(
    "Explained Variance Ratio:"
)

print(
    pca.explained_variance_ratio_
)
plt.savefig("../figures/figure1a.png")
plt.savefig("../figures/figure1c.png")
# Out:
# Explained Variance Ratio:
# [0.77857624]
